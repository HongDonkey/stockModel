# %% [markdown]
# # 안정적인 기업에 장기투자할 목적으로 하락세를 기다림
# # 시가총액이 높은 50개의 기업의 종가가 5일 연속 하락세일 경우 매수 신호를 보냄

# %%
import FinanceDataReader as web
from datetime import date, timedelta
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %matplotlib inline

# %%
url = "https://finance.naver.com/sise/sise_market_sum.nhn?page=1"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'lxml')

stock_head = soup.find("thead").find_all("th")
data_head = [head.get_text() for head in stock_head]

stock_list = soup.find("table", attrs={"class": "type_2"}).find("tbody").find_all("tr")
companyList=[]
for stock in stock_list:
     if len(stock) > 1 :
        companyName=stock.get_text().split()[1]
        companyList.append(companyName)

print(companyList)
# Out:
# ['삼성전자', 'SK하이닉스', 'NAVER', '삼성전자우', '삼성바이오로직스', 'LG화학', '카카오', '삼성SDI', '현대차', '셀트리온', '카카오뱅크', '기아', 'POSCO', '크래프톤', 'SK이노베이션', '현대모비스', '삼성물산', 'SK텔레콤', 'KB금융', 'LG전자', 'LG생활건강', '신한지주', 'SK바이오사이언스', 'SK', 'HMM', 'SK아이이테크놀로지', '한국전력', '삼성생명', 'LG', '하나금융지주', '삼성전기', 'S-Oil', '포스코케미칼', '엔씨소프트', '삼성에스디에스', '대한항공', 'KT&G', '하이브', '삼성화재', '두산중공업', '아모레퍼시픽', '넷마블', '고려아연', '롯데케미칼', '현대중공업', 'KT', '한온시스템', '한화솔루션', '우리금융지주', 'SK바이오팜']

# %%
codeList=[]
market = "KOSPI"
targetMarket = web.StockListing(market)

for i in range(len(companyList)):
    code = targetMarket.loc[targetMarket.Name == companyList[i]].Symbol.item()
    codeList.append(code)
#     return code

# %%
codeList
# Out:
# ['005930',
#  '000660',
#  '035420',
#  '005935',
#  '207940',
#  '051910',
#  '035720',
#  '006400',
#  '005380',
#  '068270',
#  '323410',
#  '000270',
#  '005490',
#  '259960',
#  '096770',
#  '012330',
#  '028260',
#  '017670',
#  '105560',
#  '066570',
#  '051900',
#  '055550',
#  '302440',
#  '034730',
#  '011200',
#  '361610',
#  '015760',
#  '032830',
#  '003550',
#  '086790',
#  '009150',
#  '010950',
#  '003670',
#  '036570',
#  '018260',
#  '003490',
#  '033780',
#  '352820',
#  '000810',
#  '034020',
#  '090430',
#  '251270',
#  '010130',
#  '011170',
#  '329180',
#  '030200',
#  '018880',
#  '009830',
#  '316140',
#  '326030']

# %%
# def companyStock():
today = date.today()
startday = date.today() - timedelta(720)
yesterday = date.today() - timedelta(1)
for i in range(len(codeList)):
    samsungStock = web.DataReader(codeList[i], startday, yesterday)
#     return samsungStock
print(samsungStock)
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2020-07-02   98000  127000   98000  127000    698642       NaN
# 2020-07-03  165000  165000  165000  165000    711921  0.299213
# 2020-07-06  214500  214500  193500  214500   7126211  0.300000
# 2020-07-07  219000  269500  210000  216500  10105187  0.009324
# 2020-07-08  214500  225000  198000  217000   5990009  0.002309
# ...            ...     ...     ...     ...       ...       ...
# 2021-09-16  113500  114000  112500  114000    105664  0.008850
# 2021-09-17  113500  114000  112000  113500    153055 -0.004386
# 2021-09-23  111500  112000  108000  109500    323144 -0.035242
# 2021-09-24  110000  110500  107000  107000    224301 -0.022831
# 2021-09-27  107000  109500  107000  108000    120166  0.009346
#
# [306 rows x 6 columns]

# %%
url = "https://finance.naver.com/sise/sise_market_sum.nhn?page=1"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'lxml')

stock_head = soup.find("thead").find_all("th")
data_head = [head.get_text() for head in stock_head]

stock_list = soup.find("table", attrs={"class": "type_2"}).find("tbody").find_all("tr")
companyList=[]
for stock in stock_list:
     if len(stock) > 1 :
        companyName=stock.get_text().split()[1]
        companyList.append(companyName)

        
codeList=[]
market = "KOSPI"
targetMarket = web.StockListing(market)

for i in range(len(companyList)):
    code = targetMarket.loc[targetMarket.Name == companyList[i]].Symbol.item()
    codeList.append(code)
    
    today = date.today()
    startday = date.today() - timedelta(30)
    yesterday = date.today() - timedelta(1)

    componyStock = web.DataReader(codeList[i], startday, yesterday)

    
    cnt = 0
    for j in range(len(companyList)-1):
        if(componyStock['Close'][j+1] < componyStock['Close'][j]):
#         print(samsungStock['Close'][i])
            cnt+=1
       
        else:
            print(companyList[i], "(이)가 1주 연속 하락하지는 않았지만")
            break;
            
            if(cnt == 5):
                print("★1주 연속 하락세입니다. 지금 구매하세요★")
                break;
    print("최근", cnt, "일 동안 주가가 하락하였습니다")
    print("=======================================")
# Out:
# 삼성전자 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# SK하이닉스 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# NAVER (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성전자우 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성바이오로직스 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# LG화학 (이)가 1주 연속 하락하지는 않았지만
# 최근 3 일 동안 주가가 하락하였습니다
# =======================================
# 카카오 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성SDI (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 현대차 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 셀트리온 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 카카오뱅크 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 기아 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# POSCO (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 크래프톤 (이)가 1주 연속 하락하지는 않았지만
# 최근 1 일 동안 주가가 하락하였습니다
# =======================================
# SK이노베이션 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 현대모비스 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성물산 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# SK텔레콤 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# KB금융 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# LG전자 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# LG생활건강 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 신한지주 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# SK바이오사이언스 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# SK (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# HMM (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# SK아이이테크놀로지 (이)가 1주 연속 하락하지는 않았지만
# 최근 1 일 동안 주가가 하락하였습니다
# =======================================
# 한국전력 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성생명 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# LG (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 하나금융지주 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성전기 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# S-Oil (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 포스코케미칼 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 엔씨소프트 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성에스디에스 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 대한항공 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# KT&G (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 하이브 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 삼성화재 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 두산중공업 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 아모레퍼시픽 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 넷마블 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 고려아연 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 롯데케미칼 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 현대중공업 (이)가 1주 연속 하락하지는 않았지만
# 최근 1 일 동안 주가가 하락하였습니다
# =======================================
# KT (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 한온시스템 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 한화솔루션 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# 우리금융지주 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
# SK바이오팜 (이)가 1주 연속 하락하지는 않았지만
# 최근 0 일 동안 주가가 하락하였습니다
# =======================================
